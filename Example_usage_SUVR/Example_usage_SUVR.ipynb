# %%
import numpy as np
from nilearn import plotting, image

from dynamicpet.temporalobject import TemporalMatrix
from dynamicpet.kineticmodel.suvr import SUVR
from dynamicpet.petbids.petbidsimage import load

# %%
# Load the PET image
pet_img  = image.load_img('C:/Users/gongz3/OneDrive - National Institutes of Health/Documents/Dynamic_PET/dynamicpet/Example_usage_SUVR/example_18FAV45.nii')

# Plot the image
plotting.plot_img(pet_img , display_mode='ortho', threshold='auto')

# Show the plot
plotting.show()

# %%
# Load the mask image
mask_img = image.load_img('C:/Users/gongz3/OneDrive - National Institutes of Health/Documents/Dynamic_PET/dynamicpet/Example_usage_SUVR/example_18FAV45_reference.nii')

# Plot the mask position
plotting.plot_stat_map(mask_img, bg_img=pet_img, display_mode='ortho', threshold=0, alpha=1)

# Show the mask
plotting.show()

# %%
# !kineticmodel "C:/Users/gongz3/OneDrive - National Institutes of Health/Documents/Dynamic_PET/dynamicpet/Example_usage_SUVR/example_18FAV45.nii" --model SUVR --refmask "C:/Users/gongz3/OneDrive - National Institutes of Health/Documents/Dynamic_PET/dynamicpet/Example_usage_SUVR/example_18FAV45_reference.nii" --outputdir "C:/Users/gongz3/OneDrive - National Institutes of Health/Documents/Dynamic_PET/dynamicpet/Example_usage_SUVR/" --fwhm 5
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\gongz3\Anaconda3\envs\Hackthon\Scripts\kineticmodel.exe\__main__.py", line 7, in <module>
#   File "C:\Users\gongz3\Anaconda3\envs\Hackthon\Lib\site-packages\click\core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gongz3\Anaconda3\envs\Hackthon\Lib\site-packages\click\core.py", line 1078, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "C:\Users\gongz3\Anaconda3\envs\Hackthon\Lib\site-packages\click\core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gongz3\Anaconda3\envs\Hackthon\Lib\site-packages\click\core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
